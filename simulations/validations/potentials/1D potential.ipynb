# %%
from pathlib import Path
home = str(Path.home())
import sys
sys.path.append('{}/prog/msm/lib'.format(home))

# %%
import numpy as np
from simlib import *
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.set_cmap('rainbow')

# %%
gaussians = []
gaussians.append(gaussian(A = np.ones(1),
                          M = np.array([-3]),
                          S = np.ones(1)))
gaussians.append(gaussian(A = np.ones(1),
                          M = np.array([3]),
                          S = np.ones(1)))
# Out:
# I have 1 dimensions!
# I have 1 dimensions!

# %%
xs = np.arange(-10, 10, 0.1)
U = potential(gaussians)
ys = [U.get_value([x]) for x in xs]
Fs = [U.get_force([x]) for x in xs]
plt.plot(xs, ys)
plt.plot(xs, Fs)
# Out:
# I'm a potential. I have 1 dimensions!
