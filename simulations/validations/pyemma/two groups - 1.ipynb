# %%
from pathlib import Path
home = str(Path.home())
import sys
sys.path.append('{}/prog/msm/lib'.format(home))

# %%
import numpy as np
from simlib import *
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.set_cmap('rainbow')
import pyemma
# Out:
# /home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/__init__.py:130: UserWarning: You are not using the latest release of PyEMMA. Latest is 2.5.5, you have 2.5.4.
#   .format(latest=latest, current=current), category=UserWarning)

# %%
gaussians = []
m = 5
dm = 15

# Group 1
gaussians.append(gaussian(A=np.ones(2),
                          M=np.array([-4,2]),
                          S=np.ones(2)))
gaussians.append(gaussian(A=np.ones(2),
                          M=np.array([-4,-2]),
                          S=np.ones(2)))
# Group 1
gaussians.append(gaussian(A=np.ones(2),
                          M=np.array([4,2]),
                          S=np.ones(2)))
gaussians.append(gaussian(A=np.ones(2),
                          M=np.array([4,-2]),
                          S=np.ones(2)))

# %%
x = np.arange(-10, 10, 0.1)
y = np.arange(-10, 10, 0.1)
xx, yy = np.meshgrid(x, y, sparse=True)
z = np.sum(g.get_value([xx, yy]) for g in gaussians)
h = plt.contourf(x,y,z)

# %%
x0 = 0.0
parameters = {
    'name': 'equilibrium_test',
    'num_steps': 5000000,
    'num_dim': 2,
    'num_particles': 4,
    'KBT': 1,
    'Ddt': 0.01,
    'x0': np.array([[-4,-4,4,4],
                    [-2,2,-2,2]]),
    'potential': potential(gaussians)
}

# %%
Xs = simulate(parameters)
# Out:
# HBox(children=(IntProgress(value=0, max=4999999), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b9ae05016bd4> in <module>()
# ----> 1 Xs = simulate(parameters)
#
# ~/prog/msm/lib/simlib.py in simulate(params)
#     118         drift = np.zeros(shape=(num_dim, num_particles))
#     119         for i in range(num_particles):
# --> 120             drift[:,i] = A * U.get_force(Xs[t-1,:,i])
#     121         noise = B * np.random.normal(size=(num_dim, num_particles))
#     122         Xs[t,:,:] = Xs[t-1,:,:] + drift + noise
#
# ~/prog/msm/lib/simlib.py in get_force(self, pos)
#      55         # TODO: This needs to be properly vectorized
#      56         norm_factor = self.KBT / np.sum([g.get_value(pos)
# ---> 57                                          for g in self.gaussians])
#      58         force = np.zeros(self.num_dims)
#      59         for d in range(self.num_dims):
#
# ~/prog/msm/lib/simlib.py in <listcomp>(.0)
#      55         # TODO: This needs to be properly vectorized
#      56         norm_factor = self.KBT / np.sum([g.get_value(pos)
# ---> 57                                          for g in self.gaussians])
#      58         force = np.zeros(self.num_dims)
#      59         for d in range(self.num_dims):
#
# ~/prog/msm/lib/simlib.py in get_value(self, pos)
#      36
#      37     def get_value(self, pos):
# ---> 38         return np.prod([self.get_1d_value(x, i) for i, x in enumerate(pos)])
#      39
#      40
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in prod(a, axis, dtype, out, keepdims)
#    2454
#    2455
# -> 2456 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue):
#    2457     """
#    2458     Return the product of array elements over a given axis.
#
# KeyboardInterrupt:

# %%
Xs = np.load('Xs_two_groups_1.npy')
# Out:
# [[-4.         -2.        ]
#  [-3.71641041 -2.12960364]
#  [-3.65497395 -2.03693485]
#  ...
#  [ 4.25020437 -1.68667899]
#  [ 4.12582143 -1.93962276]
#  [ 3.96747991 -1.8994577 ]]

# %%
fig, ax = plt.subplots()
hist = ax.hist2d(Xs[:,0], Xs[:,1], bins=75)

# %%
Xs_all = np.vstack((Xs[:,:,0], Xs[:,:,1], Xs[:,:,2], Xs[:,:,3]))

# %%
cluster = pyemma.coordinates.cluster_kmeans(Xs, k=4, max_iter=50)
# Out:
# HBox(children=(HBox(children=(Label(value='initialize kmeans++ centers'),), layout=Layout(max_width='35%', min…
# HBox(children=(HBox(children=(Label(value='kmeans iterations'),), layout=Layout(max_width='35%', min_width='35…

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
pyemma.plots.plot_feature_histograms(Xs, feature_labels=['$x$', '$y$'], ax=axes[0])
pyemma.plots.plot_density(*Xs.T, ax=axes[1], cbar=False, alpha=0.1)
axes[1].scatter(*cluster.clustercenters.T, s=15, c='C1')
axes[1].set_xlabel('$x$')
axes[1].set_ylabel('$y$')
axes[1].set_xlim(-7, 7)
axes[1].set_ylim(-7, 7)
axes[1].set_aspect('equal')
fig.tight_layout()

# %%
lags = np.linspace(1, 1500, 5).astype(int)
its = pyemma.msm.its(cluster.dtrajs, lags=lags, nits=4, errors='bayes')
pyemma.plots.plot_implied_timescales(its, ylog=False);
# Out:
# HBox(children=(HBox(children=(Label(value='estimating BayesianMSM'),), layout=Layout(max_width='35%', min_widt…
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-11:
# Traceback (most recent call last):
# Process ForkPoolWorker-9:
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 138, in _estimate_param_scan_worker
#     estimator.estimate(X, **params)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 171, in estimate
#     return super(BayesianMSM, self).estimate(dtrajs, **kw)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 214, in estimate
#     return super(_MSMEstimator, self).estimate(dtrajs, **kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 415, in estimate
#     self._model = self._estimate(X)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 177, in _estimate
#     _MLMSM._estimate(self, dtrajs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 1040, in _estimate
#     dtrajstats = self._get_dtraj_stats(dtrajs)
# Process ForkPoolWorker-12:
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 191, in _get_dtraj_stats
#     mincount_connectivity=self.mincount_connectivity)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/_dtraj_stats.py", line 229, in count_lagged
#     self._C = msmest.effective_count_matrix(self._dtrajs, lag)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/api.py", line 284, in effective_count_matrix
#     return sparse.effective_counts.effective_count_matrix(dtrajs, lag, average=average, mact=mact, n_jobs=n_jobs, callback=callback)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 262, in effective_count_matrix
#     n_jobs=n_jobs, callback=callback)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 188, in statistical_inefficiencies
#     truncate_acf=truncate_acf, mact=mact)
# Traceback (most recent call last):
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/util/statistics.py", line 234, in statistical_inefficiency
#     acf += np.sum(prod)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 138, in _estimate_param_scan_worker
#     estimator.estimate(X, **params)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 171, in estimate
#     return super(BayesianMSM, self).estimate(dtrajs, **kw)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 214, in estimate
#     return super(_MSMEstimator, self).estimate(dtrajs, **kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 415, in estimate
#     self._model = self._estimate(X)
# Traceback (most recent call last):
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 177, in _estimate
#     _MLMSM._estimate(self, dtrajs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 1040, in _estimate
#     dtrajstats = self._get_dtraj_stats(dtrajs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 191, in _get_dtraj_stats
#     mincount_connectivity=self.mincount_connectivity)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/_dtraj_stats.py", line 229, in count_lagged
#     self._C = msmest.effective_count_matrix(self._dtrajs, lag)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 138, in _estimate_param_scan_worker
#     estimator.estimate(X, **params)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/api.py", line 284, in effective_count_matrix
#     return sparse.effective_counts.effective_count_matrix(dtrajs, lag, average=average, mact=mact, n_jobs=n_jobs, callback=callback)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 171, in estimate
#     return super(BayesianMSM, self).estimate(dtrajs, **kw)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 262, in effective_count_matrix
#     n_jobs=n_jobs, callback=callback)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 188, in statistical_inefficiencies
#     truncate_acf=truncate_acf, mact=mact)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 214, in estimate
#     return super(_MSMEstimator, self).estimate(dtrajs, **kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/util/statistics.py", line 233, in statistical_inefficiency
#     prod = x[:Nx-lag] * x[lag:]
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 415, in estimate
#     self._model = self._estimate(X)
# KeyboardInterrupt
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 177, in _estimate
#     _MLMSM._estimate(self, dtrajs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 1040, in _estimate
#     dtrajstats = self._get_dtraj_stats(dtrajs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 138, in _estimate_param_scan_worker
#     estimator.estimate(X, **params)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 191, in _get_dtraj_stats
#     mincount_connectivity=self.mincount_connectivity)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 171, in estimate
#     return super(BayesianMSM, self).estimate(dtrajs, **kw)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 214, in estimate
#     return super(_MSMEstimator, self).estimate(dtrajs, **kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/_dtraj_stats.py", line 229, in count_lagged
#     self._C = msmest.effective_count_matrix(self._dtrajs, lag)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py", line 415, in estimate
#     self._model = self._estimate(X)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/api.py", line 284, in effective_count_matrix
#     return sparse.effective_counts.effective_count_matrix(dtrajs, lag, average=average, mact=mact, n_jobs=n_jobs, callback=callback)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 262, in effective_count_matrix
#     n_jobs=n_jobs, callback=callback)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/bayesian_msm.py", line 177, in _estimate
#     _MLMSM._estimate(self, dtrajs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 188, in statistical_inefficiencies
#     truncate_acf=truncate_acf, mact=mact)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 1040, in _estimate
#     dtrajstats = self._get_dtraj_stats(dtrajs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/maximum_likelihood_msm.py", line 191, in _get_dtraj_stats
#     mincount_connectivity=self.mincount_connectivity)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/util/statistics.py", line 234, in statistical_inefficiency
#     acf += np.sum(prod)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/_dtraj_stats.py", line 229, in count_lagged
#     self._C = msmest.effective_count_matrix(self._dtrajs, lag)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/api.py", line 284, in effective_count_matrix
#     return sparse.effective_counts.effective_count_matrix(dtrajs, lag, average=average, mact=mact, n_jobs=n_jobs, callback=callback)
# KeyboardInterrupt
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 262, in effective_count_matrix
#     n_jobs=n_jobs, callback=callback)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/estimation/sparse/effective_counts.py", line 188, in statistical_inefficiencies
#     truncate_acf=truncate_acf, mact=mact)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/msmtools/util/statistics.py", line 234, in statistical_inefficiency
#     acf += np.sum(prod)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py", line 1882, in sum
#     out=out, **kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py", line 32, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a83326e8bbe6> in <module>()
#       1 lags = np.linspace(1, 1500, 5).astype(int)
# ----> 2 its = pyemma.msm.its(cluster.dtrajs, lags=lags, nits=4, errors='bayes')
#       3 pyemma.plots.plot_implied_timescales(its, ylog=False);
#
# ~/anaconda3/lib/python3.6/site-packages/pyemma/msm/api.py in timescales_msm(dtrajs, lags, nits, reversible, connected, weights, errors, nsamples, n_jobs, show_progress, mincount_connectivity)
#     226     itsobj = _ImpliedTimescales(estimator, lags=lags, nits=nits, n_jobs=n_jobs,
#     227                                 show_progress=show_progress)
# --> 228     itsobj.estimate(dtrajs)
#     229     return itsobj
#     230
#
# ~/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/implied_timescales.py in estimate(self, X, **params)
#     150             how many subprocesses to start to estimate the models for each lag time.
#     151         """
# --> 152         return super(ImpliedTimescales, self).estimate(X, **params)
#     153
#     154     def _estimate(self, dtrajs):
#
# ~/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py in estimate(self, X, **params)
#     413         if params:
#     414             self.set_params(**params)
# --> 415         self._model = self._estimate(X)
#     416         # ensure _estimate returned something
#     417         assert self._model is not None
#
# ~/anaconda3/lib/python3.6/site-packages/pyemma/msm/estimators/implied_timescales.py in _estimate(self, dtrajs)
#     205             models, estimators = estimate_param_scan(self.estimator, dtrajs, param_sets, failfast=False,
#     206                                                      return_estimators=True, n_jobs=self.n_jobs,
# --> 207                                                      progress_reporter=pg, return_exceptions=True)
#     208         self._estimators = estimators
#     209
#
# ~/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py in estimate_param_scan(estimator, X, param_sets, evaluate, evaluate_args, failfast, return_estimators, n_jobs, progress_reporter, show_progress, return_exceptions)
#     352             res_async = [pool.apply_async(_estimate_param_scan_worker, a, callback=callback,
#     353                                           **opt_args) for a in args]
# --> 354             res = [x.get() for x in res_async]
#     355
#     356     # if n_jobs=1 don't invoke the pool, but directly dispatch the iterator
#
# ~/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py in <listcomp>(.0)
#     352             res_async = [pool.apply_async(_estimate_param_scan_worker, a, callback=callback,
#     353                                           **opt_args) for a in args]
# --> 354             res = [x.get() for x in res_async]
#     355
#     356     # if n_jobs=1 don't invoke the pool, but directly dispatch the iterator
#
# ~/anaconda3/lib/python3.6/site-packages/multiprocess/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# ~/anaconda3/lib/python3.6/site-packages/multiprocess/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-13:
# Traceback (most recent call last):
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/pool.py", line 108, in worker
#     task = get()
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/queues.py", line 345, in get
#     with self._rlock:
#   File "/home/psapir/anaconda3/lib/python3.6/site-packages/multiprocess/synchronize.py", line 102, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt

# %%
bayesian_msm = pyemma.msm.bayesian_markov_model(cluster.dtrajs, lag=1000, conf=0.95)
sample_mean = bayesian_msm.sample_mean('timescales', k=1)
sample_conf_l, sample_conf_r = bayesian_msm.sample_conf('timescales', k=1)
print('Mean of first ITS: {:f}'.format(sample_mean[0]))
print('Confidence interval: [{:f}, {:f}]'.format(sample_conf_l[0], sample_conf_r[0]))

msm = pyemma.msm.estimate_markov_model(cluster.dtrajs, lag=1000)
print('fraction of states used = {:f}'.format(msm.active_state_fraction))
print('fraction of counts used = {:f}'.format(msm.active_count_fraction))
print(msm.stationary_distribution)
print('sum of weights = {:f}'.format(msm.pi.sum()))
# Out:
# HBox(children=(HBox(children=(Label(value='Sampling MSMs'),), layout=Layout(max_width='35%', min_width='35%'))…
# Mean of first ITS: 204164.145184
# Confidence interval: [177615.608438, 240755.187860]
# fraction of states used = 1.000000
# fraction of counts used = 1.000000
# [0.25501568 0.25026574 0.24541023 0.24930834]
# sum of weights = 1.000000

# %%
fig, ax, misc = pyemma.plots.plot_contour(
    *Xs.T, msm.pi[cluster.dtrajs[0]],
    cbar_label='stationary distribution',
    method='nearest', mask=True)
ax.scatter(*cluster.clustercenters.T, s=15, c='C1')
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.set_aspect('equal')
fig.tight_layout()

# %%
fig, ax, misc = pyemma.plots.plot_free_energy(
    *Xs.T,
    weights=msm.pi[cluster.dtrajs[0]],
    legacy=False)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.set_aspect('equal')
fig.tight_layout()

# %%
eigvec = msm.eigenvectors_right()
print('first eigenvector is one: {} (min={}, max={})'.format(
    np.allclose(eigvec[:, 0], 1, atol=1e-15), eigvec[:, 0].min(), eigvec[:, 0].max()))
# Out:
# first eigenvector is one: True (min=0.9999999999999822, max=1.0000000000000175)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 3))
for i, ax in enumerate(axes.flat):
    pyemma.plots.plot_contour(
        *Xs.T, eigvec[cluster.dtrajs[0], i + 1], ax=ax, cmap='seismic',
        cbar_label='{}. right eigenvector'.format(i + 2), mask=True)
    ax.scatter(*cluster.clustercenters.T, s=15, c='C1')
    ax.set_xlabel('$x$')
    ax.set_xlim(-10, 10)
    ax.set_ylim(-10, 10)
    ax.set_aspect('equal')
axes[0].set_ylabel('$y$')
fig.tight_layout()

# %%
nstates = 4
pyemma.plots.plot_cktest(msm.cktest(nstates));
# Out:
# HBox(children=(HBox(children=(Label(value='estimating MaximumLikelihoodMSM'),), layout=Layout(max_width='35%',…
