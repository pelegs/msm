# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from copy import deepcopy
from scipy import stats
import seaborn as sns
import matplotlib as mpl
import pyemma.coordinates as coor
import pyemma.msm as msm
import pyemma.plots as mplt
import matplotlib
sns.set_style('white')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-1a63c0feb98f> in <module>()
#       4 from copy import deepcopy
#       5 from scipy import stats
# ----> 6 import seaborn as sns
#       7 import matplotlib as mpl
#       8 import pyemma.coordinates as coor
#
# ImportError: No module named 'seaborn'

# %%
X = np.loadtxt('../data/short/double_well_langevin_every_100th.data')

# %%
X = X.T[1]

# %%
n_clusters = 2   # number of k-means clusters

clustering = coor.cluster_kmeans(X,k=n_clusters) # calculate clusters with kmeans
dtrajs = clustering.dtrajs
cc_x = clustering.clustercenters[:,0]
its = msm.timescales_msm(dtrajs, lags=200, nits=10)
# matplotlib.rcParams.update({'font.size': 14})
mplt.plot_implied_timescales(its, ylog=False, units='steps', linewidth=2)
# plt.xlim(0, 40); plt.ylim(0, 120);
# plt.show()
# Out:
# kmeans iterations:  20% ( 2/10) [######                            ] eta 00:01 -14-10-18 12:37:53 pyemma.coordinates.clustering.kmeans.KmeansClustering[0] INFO     Cluster centers converged after 3 steps.
# estimating MaximumLikelihoodMSM: 100% (12/12) [####################] eta 00:01 /14-10-18 12:37:55 pyemma.msm.estimators.implied_timescales.ImpliedTimescales[1] WARNING  Changed user setting nits to the number of available timescales nits=1

# %%
cc_x = clustering.clustercenters[:,0]
plt.plot(X[::1000],'-o')
plt.scatter(np.zeros_like(cc_x),cc_x)

# %%
its = msm.timescales_msm(dtrajs, lags=20, nits=10)
# Out:
# estimating MaximumLikelihoodMSM: 100% (7/7) [######################] eta 00:01 /14-10-18 12:38:16 pyemma.msm.estimators.implied_timescales.ImpliedTimescales[2] WARNING  Changed user setting nits to the number of available timescales nits=1

# %%
# plt.ylim((0,10))
# plt.xlim((0,10))

mplt.plot_implied_timescales(its, ylog=False, units='steps', linewidth=2)
# plt.ylim((0,10))
plt.plot(np.mean(np.diff(s))/2*np.ones(18))
# plt.xlim((0,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8b3513645b96> in <module>()
#       4 mplt.plot_implied_timescales(its, ylog=False, units='steps', linewidth=2)
#       5 # plt.ylim((0,10))
# ----> 6 plt.plot(np.mean(np.diff(s))/2*np.ones(18))
#       7 # plt.xlim((0,10))
#
# NameError: name 's' is not defined

# %%
np.mean(np.diff(s))/2 * np.ones_like(its)
# Out:
# 15223.4

# %%
its.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-1d470ec6c74b> in <module>()
# ----> 1 its.shape
#
# AttributeError: 'ImpliedTimescales' object has no attribute 'shape'

# %%
sns.kdeplot(X[::1000])

# %% [markdown]
# How much time does it take until a crossing event?

# %%
s  = [i for i,x in enumerate(X[:-1]) if X[i]*X[i+1]<0]

# %% [markdown]
# What is the mean time of crossing?

# %%
np.mean(np.diff(s))/its.get_timescales()[-1][0]
# Out:
# 1.8294998715949968

# %%
plt.plot(s)

# %%
h = plt.hist(np.abs(np.diff(X)),100)

# %%
np.mean(np.abs(np.diff(X)))
# Out:
# 1.1433423209109665

# %%
its.get_timescales()[-1][0]
# Out:
# 16642.143829972414
