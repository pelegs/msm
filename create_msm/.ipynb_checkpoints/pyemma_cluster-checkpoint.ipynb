# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from copy import deepcopy
from scipy import stats
import seaborn as sns
import matplotlib as mpl
import pyemma.coordinates as coor
import pyemma.msm as msm
import pyemma.plots as mplt
import matplotlib
sns.set_style('white')
# Out:
# /home/psapir/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:278: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1a63c0feb98f> in <module>()
#       6 import seaborn as sns
#       7 import matplotlib as mpl
# ----> 8 import pyemma.coordinates as coor
#       9 import pyemma.msm as msm
#      10 import pyemma.plots as mplt
#
# ModuleNotFoundError: No module named 'pyemma'

# %%
X = np.loadtxt('/home/avolkha1/pelegs/double_well2.data')

# %%
X = X.T[1]

# %%
n_clusters = 2   # number of k-means clusters

clustering = coor.cluster_kmeans(X,k=n_clusters) # calculate clusters with kmeans
dtrajs = clustering.dtrajs
cc_x = clustering.clustercenters[:,0]
its = msm.timescales_msm(dtrajs, lags=200, nits=10)
# matplotlib.rcParams.update({'font.size': 14})
mplt.plot_implied_timescales(its, ylog=False, units='steps', linewidth=2)
# plt.xlim(0, 40); plt.ylim(0, 120);
# plt.show()
# Out:
# 31-08-18 14:30:21 pyemma.coordinates.clustering.kmeans.KmeansClustering[10] INFO     Cluster centers converged after 2 steps.
# 31-08-18 14:30:52 pyemma.msm.estimators.implied_timescales.ImpliedTimescales[11] WARNING  Changed user setting nits to the number of available timescales nits=1

# %%
cc_x = clustering.clustercenters[:,0]
plt.plot(X[::1000],'-o')
plt.scatter(np.zeros_like(cc_x),cc_x)

# %%
its = msm.timescales_msm(dtrajs, lags=20, nits=10)
# Out:
# 31-08-18 14:31:11 pyemma.msm.estimators.implied_timescales.ImpliedTimescales[12] WARNING  Changed user setting nits to the number of available timescales nits=1

# %%
# plt.ylim((0,10))
# plt.xlim((0,10))

mplt.plot_implied_timescales(its, ylog=False, units='steps', linewidth=2)
# plt.ylim((0,10))
plt.plot(np.mean(np.diff(s))/2*np.ones(18))
# plt.xlim((0,10))

# %%
np.mean(np.diff(s))/2*np.ones_like(its)
# Out:
# 2176.3728070175439

# %%
its.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-818e9bbe4e6f> in <module>()
# ----> 1 its.shape
#
# AttributeError: 'ImpliedTimescales' object has no attribute 'shape'

# %%
sns.kdeplot(X[::1000])

# %% [markdown]
# How much time does it take until a crossing event?

# %%
s  = [i for i,x in enumerate(X[:-1]) if X[i]*X[i+1]<0]

# %% [markdown]
# What is the mean time of crossing?

# %%
np.mean(np.diff(s))/its.get_timescales()[-1][0]
# Out:
# 1.7854195789246676

# %%
plt.plot(s)

# %%
h = plt.hist(np.abs(np.diff(X)),100)

# %%
np.mean(np.abs(np.diff(X)))
# Out:
# 1.4125626820266282

# %%
its.get_timescales()[-1][0]
# Out:
# 2437.9398912252791
