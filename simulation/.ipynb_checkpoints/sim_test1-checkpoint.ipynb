# %%
from matplotlib import pyplot as plt 
import numpy as np  
# %matplotlib inline

# %%
import sys
sys.path.append('../lib')
from simlib import *

# %%
U = harmonic_potential()

# %%
ts, xs, hist, bin_edges = simulate('test1', U, max_t=100000)
xs = xs[:-1]

# %%
plt.plot(ts, xs)

# %%
plt.plot(bin_edges[:-1], hist)
#plt.plot(bin_edges[:-1], U.get_expected_probability(bin_edges[:-1]))

# %%
gs = [gaussian(-2), gaussian(2)]
V = gaussian_potential(gs)

# %%
ts, xs, hist, bin_edges = simulate('test2', V, max_t=100000)
xs = xs[:-1]
plt.plot(bin_edges[:-1], hist)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-bb0bdd13b3ef> in <module>()
# ----> 1 ts, xs, hist, bin_edges = simulate('test2', V, max_t=100000)
#       2 xs = xs[:-1]
#       3 plt.plot(bin_edges[:-1], hist)
#
# ~/prog/msm/lib/simlib.py in simulate(name, potential, method, max_t, dt, dstep, D, KT, x0, drift, noise)
#      82                 vdt += A * potential.get_force(xs[-1])
#      83             if noise:
# ---> 84                 vdt += B * np.random.normal()
#      85             xs.append(xs[-1] + vdt)
#      86         else:
#
# KeyboardInterrupt:
